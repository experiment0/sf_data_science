# %%
from classes.Navigation import Navigation

navigation = Navigation('3_2_eda_newbies.ipynb')

navigation.display_header()
# Out:
# [Главная](./1_main.ipynb) &raquo; Исследование данных таблицы `data_newbies`
# # Исследование данных таблицы `data_newbies`

# %% [markdown]
# ## Оглавление
# - [Загрузка данных](#item_load)
# - [Исследование распределения признаков в разрезе целевой переменной `deposit`](#item_distribution_by_target)
# - [Исследование корреляции признаков](#item_correlation)
#     - [Построение матрицы корреляции и диаграммы корреляции признаков с целевой переменной `deposit`](#item_correlation_by_target)
#     - [Взаимосвязь признаков `age` и `marital`](#item_relation_age_marital)
#     - [Взаимосвязь признаков `month` и `housing`](#item_relation_month_housing)
#     - [Взаимосвязь признаков `month` и `contact`](#item_relation_month_contact)
#     - [Взаимосвязь признаков `duration` и `deposit`](#item_relation_duration_deposit)
#     - [Взаимосвязь признаков `job` и `education`](#item_relation_job_education)

# %% [markdown]
# ## Загрузка данных <a id="item_load"></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from classes.PrepareDataNewbies import PrepareDataNewbies

from functions.prepare_data import (
    get_data_with_label_encoded_columns,
)
from functions.display_content import (
    display_fields_distribution_by_target,
    display_fields_correlation,
    display_relationship_features,
)

# %%
# Загрузим данные
data_source = pd.read_csv('./data/bank_fin.csv', sep=';')

prepareData = PrepareDataNewbies(data_source)

prepareData.specific_prepare_data()

# Получим обработанные данные таблицы data_newbies
data_newbies = prepareData.get_data()

# %% [markdown]
# ## Исследование распределения признаков в разрезе целевой переменной `deposit` <a id="item_distribution_by_target"></a>

# %%
display_fields_distribution_by_target(data_newbies)
# Out:
# ### Признак `balance` (баланс)
# Посмотрим на распределение признака `balance` в разрезе целевой переменной `deposit`.
# ### Признак `age` (возраст)
# Посмотрим на распределение признака `age` в разрезе целевой переменной `deposit`.
# ### Признак `education` (уровень образования)
# Посмотрим на распределение признака `education` в разрезе целевой переменной `deposit`.
# **Перевод значений признака `education`**
#     Значение                Перевод
# 0  secondary    среднее образование
# 1   tertiary     высшее образование
# 2    primary  начальное образование
# 3    unknown             неизвестно
# ### Признак `marital` (семейное положение)
# Посмотрим на распределение признака `marital` в разрезе целевой переменной `deposit`.
# **Перевод значений признака `marital`**
#    Значение    Перевод
# 0   married      женат
# 1    single   одинокий
# 2  divorced  в разводе
# ### Признак `job` (сфера занятости)
# ...

# %% [markdown]
# ## Исследование корреляции признаков <a id="item_correlation"></a>
#
# ### Построение матрицы корреляции и диаграммы корреляции признаков с целевой переменной `deposit` <a id="item_correlation_by_target"></a>

# %%
# Для построения матрицы корреляции к столбцам с типом `object` 
# временно применим порядковое кодирование с помощью `LabelEncoder`
data_newbies_le = get_data_with_label_encoded_columns(data_newbies)

display_fields_correlation(data_newbies_le, 0.3, 'spearman')
# Out:
# Построим матрицу корреляции.
# Посмотрим на пары признаков с коэффициентом корреляции больше, чем `0.3`
# [(['age', 'marital'], -0.48),
#  (['housing', 'month'], 0.31),
#  (['contact', 'month'], 0.39),
#  (['duration', 'deposit'], 0.57)]

# %% [markdown]
# **Рассмотрим более подробно взаимосвязи некоторых признаков.**

# %% [markdown]
# <a id="item_relation_age_marital"></a>

# %%
display_relationship_features(
    data_newbies,
    'age',
    feature_target='marital',
    title='Распределение возраста клиентов в разрезе семейного положения ',
)
# Out:
# ### Взаимосвязь признаков `age` и `marital`
# Вспомним описание признаков:
# - `age` - возраст
# - `marital` - семейное положение

# %% [markdown]
# <a id="item_relation_month_housing"></a>

# %%
display_relationship_features(
    data_newbies,
    'month',
    feature_target='housing',
)
# Out:
# ### Взаимосвязь признаков `month` и `housing`
# Вспомним описание признаков:
# - `month` - месяц, в котором был последний контакт
# - `housing` - имеется ли кредит на жильё

# %% [markdown]
# <a id="item_relation_month_contact"></a>

# %%
display_relationship_features(
    data_newbies,
    'month',
    feature_target='contact',
)
# Out:
# ### Взаимосвязь признаков `month` и `contact`
# Вспомним описание признаков:
# - `month` - месяц, в котором был последний контакт
# - `contact` - тип контакта с клиентом

# %% [markdown]
# <a id="item_relation_duration_deposit"></a>

# %%
display_relationship_features(
    data_newbies,
    'duration',
    feature_target='deposit',
    #title='Распределения ',
)
# Out:
# ### Взаимосвязь признаков `duration` и `deposit`
# Вспомним описание признаков:
# - `duration` - продолжительность контакта в секундах
# - `deposit` - открыл ли клиент депозит

# %% [markdown]
# <a id="item_relation_job_education"></a>

# %%
display_relationship_features(
    data_newbies,
    'job',
    feature_target='education',
    title='Сфера занятости в разрезе уровня образования',
)
# Out:
# ### Взаимосвязь признаков `job` и `education`
# Вспомним описание признаков:
# - `job` - сфера занятости
# - `education` - уровень образования

# %%
navigation.display_backlink()
# Out:
# **Вернуться к файлу &laquo;[Главная](./1_main.ipynb)&raquo;**
