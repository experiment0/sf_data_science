# %% [markdown]
# # ВВП на душу населения (в долл. США)

# %%
import pandas as pd

from helpers import get_omissions

from warnings import simplefilter
simplefilter('ignore')

# %% [markdown]
# Эти данные можно найти на сайте "Группы Всемирного банка" по ссылке
#
# https://data.worldbank.org/indicator/NY.GDP.PCAP.CD?end=2020&most_recent_year_desc=true&start=2000

# %%
# Загрузим таблицу
data = pd.read_csv('../data/worldbank_gdp_per_capita.csv')

data.head(2)
# Out:
#                   Country Name Country Code                Indicator Name  \
# 0                        Aruba          ABW  GDP per capita (current US$)
# 1  Africa Eastern and Southern          AFE  GDP per capita (current US$)
#
#    Indicator Code        1960        1961        1962        1963        1964  \
# 0  NY.GDP.PCAP.CD         NaN         NaN         NaN         NaN         NaN
# 1  NY.GDP.PCAP.CD  186.132432  186.947182  197.408105  225.447007  209.005786
#
#          1965  ...          2015          2016          2017          2018  \
# 0         NaN  ...  27458.225331  27441.529662  28440.051964  30082.127645
# 1  226.883067  ...   1479.564123   1329.777824   1520.171298   1538.924188
#
#            2019          2020          2021          2022         2023  \
# 0  31096.205074  22855.932320  27200.061079  30559.533535  33984.79062
# 1   1493.780445   1344.080962   1522.590088   1628.024526   1659.51529
#
#    Unnamed: 68
# 0          NaN
# 1          NaN
#
# [2 rows x 69 columns]

# %%
# Выведем список столбцов

data.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', 'Unnamed: 68'],
#       dtype='object')

# %% [markdown]
# Нам нужны данные только за 2000 - 2020 гг.\
# Удалим лишние столбцы.

# %%
data.drop(
    columns=[
        'Country Name', 'Indicator Name', 'Indicator Code',
       '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2021', '2022', '2023', 'Unnamed: 68',
    ],
    inplace=True,
)

data.head()
# Out:
#   Country Code          2000          2001          2002          2003  \
# 0          ABW  20681.023027  20740.132583  21307.248251  21949.485996
# 1          AFE    707.120376    626.169148    625.998815    809.968139
# 2          AFG    174.930991    138.706822    178.954088    198.871116
# 3          AFW    516.932316    530.653167    616.796033    694.500939
# 4          AGO    563.733796    533.586202    882.147847    992.698979
#
#            2004          2005          2006          2007          2008  ...  \
# 0  23700.631990  24171.837133  24845.658484  26736.308944  28171.909401  ...
# 1    981.744631   1115.713956   1220.002468   1362.310651   1421.118612  ...
# 2    221.763654    254.184249    274.218554    376.223152    381.733238  ...
# 3    834.861291    989.699739   1222.550498   1393.748487   1652.189850  ...
# 4   1266.210864   1916.468422   2617.051960   3141.045980   4103.066900  ...
#
#            2011          2012          2013          2014          2015  \
# 0  25712.384302  25119.665545  25813.576727  26129.839062  27458.225331
# 1   1735.585140   1702.969258   1673.140476   1656.107642   1479.564123
# 2    606.694676    651.417134    637.087099    625.054942    565.569730
# 3   1824.722827   1920.119912   2113.316986   2204.995700   1845.767804
# 4   4615.910598   5086.027401   5057.747878   5005.999741   3213.902611
#
#            2016          2017          2018          2019          2020
# 0  27441.529662  28440.051964  30082.127645  31096.205074  22855.932320
# 1   1329.777824   1520.171298   1538.924188   1493.780445   1344.080962
# 2    522.082216    525.469771    491.337221    496.602504    510.787063
# 3   1616.843198   1560.162999   1703.896392   1783.654365   1664.249176
# 4   1807.952941   2437.259712   2538.591391   2189.855714   1449.922867
#
# [5 rows x 22 columns]

# %% [markdown]
# Здесь в столбцах:
#
# - `Country Code` - код страны
# - `2000 - 2020` - данные ВВП на душу населения в долларах США за соответствующие года
#
# Переведем данные ВВП за различные года из столбцов в строки.

# %%
data = data.melt(
    id_vars=['Country Code'],
    var_name='Year',
)
data.head()
# Out:
#   Country Code  Year         value
# 0          ABW  2000  20681.023027
# 1          AFE  2000    707.120376
# 2          AFG  2000    174.930991
# 3          AFW  2000    516.932316
# 4          AGO  2000    563.733796

# %% [markdown]
# Переименуем столбцы, чтобы их названия совпадали с основной таблицей.

# %%
data.rename(
    columns={
        'Country Code': 'SpatialDimValueCode',
        'Year': 'Period',
        'value': 'GdpPerCapita',
    },
    inplace=True,
)

# Переведем столбец 'Period' в числовой, т.к. в основной таблице он имеет тип int
data['Period'] = data['Period'].astype(int)

data.head()
# Out:
#   SpatialDimValueCode  Period  GdpPerCapita
# 0                 ABW    2000  20681.023027
# 1                 AFE    2000    707.120376
# 2                 AFG    2000    174.930991
# 3                 AFW    2000    516.932316
# 4                 AGO    2000    563.733796

# %% [markdown]
# Посмотрим на пропуски.

# %%
data.isna().sum()
# Out:
# SpatialDimValueCode      0
# Period                   0
# GdpPerCapita           163
# dtype: int64

# %% [markdown]
# Есть пропуски за определенные года.

# %%
# Загрузим таблицу с данными регионов и стран
regions_and_locations_data = pd.read_csv(
    '../data/regions_and_locations.csv'
)
regions_and_locations_data.head()
# Out:
#   ParentLocationCode ParentLocation SpatialDimValueCode      Location
# 0                AFR         Africa                 AGO        Angola
# 1                AFR         Africa                 BDI       Burundi
# 2                AFR         Africa                 BEN         Benin
# 3                AFR         Africa                 BFA  Burkina Faso
# 4                AFR         Africa                 BWA      Botswana

# %% [markdown]
# Оставим только те страны, которые есть в таблице `regions_and_locations.csv`.

# %%
# Коды стран
location_codes = list(regions_and_locations_data['SpatialDimValueCode'].unique())

# Маска для кодов стран, которые используем
mask = data['SpatialDimValueCode'].isin(location_codes)

# Удаляем строки, которые не соответствуют маске
data.drop(data[~mask].index, inplace=True)

# Снова посмотрим на пропуски
data.isna().sum()
# Out:
# SpatialDimValueCode     0
# Period                  0
# GdpPerCapita           15
# dtype: int64

# %% [markdown]
# Посмотрим подробнее, что за пропуски у нас остались.

# %%
omissions_data = get_omissions(data)

omissions_data.sort_values(by=['SpatialDimValueCode', 'Period'])
# Out:
#      SpatialDimValueCode  Period  GdpPerCapita
# 3261                 ERI    2012           NaN
# 3527                 ERI    2013           NaN
# 3793                 ERI    2014           NaN
# 4059                 ERI    2015           NaN
# 4325                 ERI    2016           NaN
# 4591                 ERI    2017           NaN
# 4857                 ERI    2018           NaN
# 5123                 ERI    2019           NaN
# 5389                 ERI    2020           NaN
# 4244                 VEN    2015           NaN
# 4510                 VEN    2016           NaN
# 4776                 VEN    2017           NaN
# 5042                 VEN    2018           NaN
# 5308                 VEN    2019           NaN
# 5574                 VEN    2020           NaN

# %%
# Посмотрим, что это за страны
mask = regions_and_locations_data['SpatialDimValueCode'].isin(['ERI', 'VEN'])
regions_and_locations_data[mask]
# Out:
#    ParentLocationCode ParentLocation SpatialDimValueCode  \
# 13                AFR         Africa                 ERI
# 78                AMR       Americas                 VEN
#
#                               Location
# 13                             Eritrea
# 78  Venezuela (Bolivarian Republic of)

# %% [markdown]
# Это Эритрея и Венесуэла (Боливарианская Республика).\
# Добавим данные с кодами регионов в таблицу `data` и заполним пропуски средним по региону.

# %%
# Создадим таблицу для объединения с data 
# и оставим в ней только коды региона и страны
regions_codes_data = regions_and_locations_data[[
    'ParentLocationCode', 'SpatialDimValueCode',
]]

# Добавим в data столбец с кодом региона
data = data.merge(
    regions_codes_data,
    on=['SpatialDimValueCode'],
    how='left',
)

data.head()
# Out:
#   SpatialDimValueCode  Period  GdpPerCapita ParentLocationCode
# 0                 AFG    2000    174.930991                EMR
# 1                 AGO    2000    563.733796                AFR
# 2                 ALB    2000   1126.683340                EUR
# 3                 ARE    2000  29865.502347                EMR
# 4                 ARG    2000   7637.014892                AMR

# %%
# Заполним пропуски средним по региону
data['GdpPerCapita'] = \
    data.groupby(['ParentLocationCode', 'Period'])['GdpPerCapita'] \
    .transform(lambda x: x.fillna(x.mean()));

# Убедимся, что пропусков нет
data.isna().sum().sum()
# Out:
# 0

# %%
# Удалим столбцы, которые больше не нужны
data.drop(columns=['ParentLocationCode'], inplace=True)

# %%
# Сохраним полученную таблицу для дальнейшего использования
data.to_csv('../data/worldbank_gdp_per_capita_prepared.csv', index=False)
